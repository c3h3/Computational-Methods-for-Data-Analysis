# %%
from everything import __future__ as PyConAPAC
# Out:
# <a href="http://tw.pycon.org/2014apac/en/" target="_blank" class="svg"><svg enable-background="new 4784.332 2788.145 461.619 152.118" height="152.118px" id="Layer_1" version="1.1" viewBox="4784.332 2788.145 461.619 152.118" width="461.619px" x="0px" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" y="0px">
# <g>
# 	<path d="M4826.781,2936.36l-6.527-25.453l3.43-8.292c0.43-1.207,0.076-2.661-0.799-3.284l-15.896-11.305   c-0.303-0.215-0.639-0.303-0.97-0.272l-0.156-0.001l-0.157,0.001c-0.331-0.03-0.666,0.057-0.969,0.272l-15.896,11.305   c-0.876,0.623-1.229,2.077-0.799,3.284l3.43,8.292l-6.526,25.453c-0.11,0.732,0.029,1.492,0.377,2.071   c0.349,0.577,0.87,0.913,1.42,0.91l18.912-0.04l0.15-0.021l0.058,0.021l0.057-0.021l0.149,0.021l18.913,0.04   c0.551,0.002,1.072-0.333,1.42-0.91C4826.751,2937.852,4826.891,2937.092,4826.781,2936.36" fill="#04556A"/>
# ...

# %%
# click the logo for more infomation!

# %%
help(PyConAPAC.call_for_proposal)
# Out:
# <pre>PyCon APAC 2014 Call for Proposal !!
#
#     PyCon APAC 2014 is now accepting all types of proposals.
#     In addition to regular and lightning talks, you can also
#     submit proposals for tutorials and for SciPy Track.
#     Please refer to the detail page below:</pre><p style="text-indent:4;font-family:monospace">&nbsp&nbsp&nbsp&nbsp<a href="http://tw.pycon.org/2014apac/en/call-for-proposals/">http://tw.pycon.org/2014apac/en/call-for-proposals/</a></p>

# %%
# %matplotlib inline

# %% [markdown]
# # Video: W02_L05_P01

# %% [markdown]
# ## Page 283 (Figure 96) at [Lecture Notes](http://spark-public.s3.amazonaws.com/compmethods/Lecture%20Note%20Packet/LectureNotePacketSciCompMeth.pdf)

# %% [markdown]
# # Video: W02_L05_P02

# %% [markdown]
# -    ## Gabor idea : fix window and go across
# -    ## Wavelet idea : change the window width, get more information

# %% [markdown]
# # Wavelet Function $\psi_{a,b}(t)$:
#
# -    ## $\psi_{a,b}(t) = \frac{1}{\sqrt{a}}\psi(\frac{t-b}{a})$
# -    ## Mother Wavelet: $\psi(t)$
# -    ## shift position by changing $b$
# -    ## scaling and adjusting width and height by changing $a$

# %% [markdown]
# # Haar (1910 ~ ):
#
# ## Haar Wavelet: $$
# \begin{eqnarray}
# \psi(x) =
# \begin{cases}
# 1       & 0 \leq x < \frac{1}{2} \\
# -1   & \frac{1}{2} \leq x < 1 \\
# 0           & otherwise
# \end{cases}
# \end{eqnarray}
# $$

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([0, 0, .5, .5, 1, 1], [0, 1, 1, -1, -1, 0])
plt.ylim(-1.25, 1.25)
plt.xlim(-.25, 1.25)
# Out:
# (-0.25, 1.25)
# /usr/lib/pymodules/python2.7/matplotlib/font_manager.py:1218: UserWarning: findfont: Font family ['monospace'] not found. Falling back to Bitstream Vera Sans
#   (prop.get_family(), self.defaultFamily[fontext]))

# %% [markdown]
# #### Ref: http://nbviewer.ipython.org/gist/anonymous/8534240

# %% [markdown]
# # Try ... to compute Fourier Transform of Haar Wavelet Function:

# %%
import numpy as np

# %%
def haar_fn(x):
    if x >= 0 and x<0.5:
        return 1
    elif x >= 0.5 and x<1:
        return -1
    else:
        return 0

    
haar_vec_fn = np.vectorize(haar_fn)

# %%
x_start = -5
x_end = 5
x_N = 301
x_vec = np.linspace(x_start,x_end,x_N)

# %%
#haar_vec_fn(x_vec)

# %%
plt.plot(x_vec, haar_vec_fn(x_vec))
plt.ylim(-1.25, 1.25)
plt.xlim(x_start, x_end)
# Out:
# (-5, 5)

# %% [markdown]
# ## Un-Shift FFT:

# %%
plt.plot(np.fft.fft(haar_vec_fn(x_vec)))
# Out:
# /usr/local/lib/python2.7/dist-packages/numpy/core/numeric.py:460: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# ## Shifted FFT:

# %%
plt.plot(np.fft.fftshift(np.fft.fft(haar_vec_fn(x_vec))))

# %% [markdown]
# ## Shifted + Absoluted FFT:
#
# -    ## Decay speed ~ $\frac{1}{\omega}$

# %%
plt.plot(np.abs(np.fft.fftshift(np.fft.fft(haar_vec_fn(x_vec)))))

# %% [markdown]
# ## FFT & inversed FFT:

# %%
plt.plot(x_vec,np.fft.ifft(np.fft.fft(haar_vec_fn(x_vec))))

# %% [markdown]
# # Haar Wavelet Properties:
#
# -    ## $\int_{-\infty}^{\infty} \psi(t) dt = 0$
# -    ## $\|\psi\|^2 = \int_{-\infty}^{\infty} \psi(t)^2 dt = 1$

# %% [markdown]
# # Video: W02_L05_P03

# %% [markdown]
# ## Integeral Transform: $$ T[f](\omega,t) = \int_t K(t,\omega)f(t) dt $$

# %% [markdown]
# ## Continuous Wavelet Transform: $$W_\psi[f](a,b) = \int_{-\infty}^{\infty} f(t) \overline{\psi_{a,b}}(t) dt  $$
#
# -    ### $a$ is scaling variable, e.g. $a = 2^n$
# -    ### $b$ is shifting variable
# -    ### Boundedness Condition of $\psi$ (for ensuring inversed W-Transform existed): $$C_\psi = \int_{-\infty}^{\infty} \frac{|\hat{\psi}(\omega)|^2}{\omega} d\omega < \infty$$

# %% [markdown]
# ## [Theorem] if $\psi$ is a wavelet and $\phi$ is bounded integrable function, then $\psi*\phi$ is wavelet!

# %% [markdown]
# # Video: W02_L05_P04

# %% [markdown]
# ## Mexican Hat Wavelet: $$\psi(t) = (1-t^2) e^{\frac{-t^2}{2}} = \psi_{1,0}$$

# %%
mex_hat_fn = lambda x:(1-x**2)*np.exp(-x**2 /2)
mex_hat_vec_fn = np.vectorize(mex_hat_fn)

# %%
x_start = -5
x_end = 5
x_N = 301
x_vec = np.linspace(x_start,x_end,x_N)

# %%
plt.plot(x_vec, mex_hat_vec_fn(x_vec))
plt.ylim(-1.25, 1.25)
plt.xlim(x_start, x_end)
# Out:
# (-5, 5)

# %% [markdown]
# ## Un-Shift FFT:

# %%
plt.plot(np.fft.fft(mex_hat_vec_fn(x_vec)))

# %% [markdown]
# ## Shifted FFT:

# %%
plt.plot(np.fft.fftshift(np.fft.fft(mex_hat_vec_fn(x_vec))))

# %% [markdown]
# ## Shifted + Absoluted FFT:

# %%
plt.plot(np.abs(np.fft.fftshift(np.fft.fft(mex_hat_vec_fn(x_vec)))))

# %% [markdown]
# ## FFT & inversed FFT:

# %%
plt.plot(x_vec,np.fft.ifft(np.fft.fft(mex_hat_vec_fn(x_vec))))

# %% [markdown]
# ## Mexican Hat Wavelet: $\psi_{a,b}(t) = \frac{1}{\sqrt{a}}\psi(\frac{t-b}{a})$

# %%
mex_hat_fn_gen = lambda a,b: lambda x: mex_hat_fn((x-b)/a)/(a**0.5)

# %%
mex_hat_0p5_0 = mex_hat_fn_gen(0.5,0)
mex_hat_0p5_0_vec = np.vectorize(mex_hat_0p5_0)
x_start = -5
x_end = 5
x_N = 301
x_vec = np.linspace(x_start,x_end,x_N)
plt.subplot(1,2,1)
plt.plot(x_vec, mex_hat_0p5_0_vec(x_vec))
plt.ylim(-1.25, 2.25)
plt.xlim(x_start, x_end)

plt.subplot(1,2,2)
plt.plot(x_vec, mex_hat_vec_fn(x_vec))
plt.ylim(-1.25, 2.25)
plt.xlim(x_start, x_end)
# Out:
# (-5, 5)

# %%
# fig, axes = plt.subplots(nrows=1, ncols=2)
# fig.tight_layout() #Or equivalently,  "plt.tight_layout()"
# plt.show()

# %%
mex_hat_0p5_0 = mex_hat_fn_gen(0.5,0)
mex_hat_0p5_0_vec = np.vectorize(mex_hat_0p5_0)

mex_hat_0p25_2 = mex_hat_fn_gen(0.25,2)
mex_hat_0p25_2_vec = np.vectorize(mex_hat_0p25_2)

x_start = -5
x_end = 5
x_N = 301
x_vec = np.linspace(x_start,x_end,x_N)

plt.plot(x_vec, mex_hat_vec_fn(x_vec),"k",
         x_vec, mex_hat_0p5_0_vec(x_vec),"b",
         x_vec, mex_hat_0p25_2_vec(x_vec),"g")
plt.ylim(-1.25, 2.25)
plt.xlim(x_start, x_end)
# Out:
# (-5, 5)

# %% [markdown]
# ## Property of Mexican Hat Wavelet:
#
# -    ## zero aveage：$$<\psi> = 0$$
# -    ## unit norm：$$\|\psi\|^2 = 1$$
# -    ## NOT Compact Support

# %%
mex_hat_0p5_0 = mex_hat_fn_gen(0.5,0)
mex_hat_0p5_0_vec = np.vectorize(mex_hat_0p5_0)

mex_hat_0p25_2 = mex_hat_fn_gen(0.25,2)
mex_hat_0p25_2_vec = np.vectorize(mex_hat_0p25_2)

mex_hat_2p0_m1 = mex_hat_fn_gen(2.0,-1.0)
mex_hat_2p0_m1_vec = np.vectorize(mex_hat_2p0_m1)

x_start = -5
x_end = 5
x_N = 301
x_vec = np.linspace(x_start,x_end,x_N)

plt.plot(x_vec, mex_hat_vec_fn(x_vec),"k",
         x_vec, mex_hat_0p5_0_vec(x_vec),"b",
         x_vec, mex_hat_0p25_2_vec(x_vec),"g",
         x_vec, mex_hat_2p0_m1_vec(x_vec),"r")
plt.ylim(-1.25, 2.25)
plt.xlim(x_start, x_end)
# Out:
# (-5, 5)

# %% [markdown]
# # Video: W02_L05_P05

# %% [markdown]
# # Wavelet Property:
# -    ## Linearity: $$W_\psi(\alpha f + \beta g) = \alpha W_\psi( f ) + \beta W_\psi( g )$$
# -    ## Translation: $$W_\psi[T_c f](a,b) = W_\psi[f](a,b-c) $$ where $T_c f (t) = f(t-c)$
# -    ## Dialation: $$W_\psi[D_c f](a,b) = \frac{1}{\sqrt{c}} W_\psi[f](\frac{a}{c},\frac{b}{c}) $$ where $D_c f (t) = \frac{1}{c} f(\frac{t}{c})$

# %% [markdown]
# # Inversed Wavelet Transform: $$ f(t) = \frac{1}{C_\psi} \int_{-\infty}^{\infty}\int_{-\infty}^{\infty} \frac{W_\psi[f](a,b) \psi_{a,b} (t)}{a^2} db da  $$

# %% [markdown]
# # Function as a linear combination of Wavelet Basis: $$ f(t) = \sum_{m,n=-\infty}^{\infty} (f,\psi_{m,n}) \psi_{m,n}(t) $$

# %% [markdown]
# # [Un-Successfully] Try ... to compute Fourier Transform of Haar Wavelet Function:

# %% [markdown]
# ### Hello pywt

# %%
import pywt

w = pywt.Wavelet('Haar')
phi, psi, x = w.wavefun(level=7)

fig, ax = plt.subplots()
ax.set_xlim(-.02,1.02)
ax.plot(x, psi);

# %% [markdown]
# #### Ref: http://jseabold.net/blog/2012/02/23/wavelet-regression-in-python/

# %%
import numpy as np
plt.plot(x,np.fft.ifft(np.fft.fft(psi)))

# %%
plt.plot(np.fft.fftshift(np.fft.fft(psi)))

# %% [markdown]
# ### Other References:
#
# -    http://www.springer.com/cda/content/document/cda_downloaddocument/9781441915443-c1.pdf?SGWID=0-0-45-1056240-p173924341
# -    http://ams.org/bookstore/pspdf/stml-63-prev.pdf
# -    [Picture Talks Everything -- 1] http://www.sharetechnote.com/html/EngMath_SumOfTimes.html
# -    [Picture Talks Everything -- 2] http://www.aanda.org/articles/aa/pdf/2001/30/aa10486.pdf
# ![](img32.gif)
