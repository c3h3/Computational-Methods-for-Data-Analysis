# %%
# %matplotlib inline

# %%
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 12

# %% [markdown]
# # Video: W04_L09_P01

# %% [markdown]
# # Image Processing
#
# -    ## Ultrasound (1M Hz ~ 20M Hz)
# -    ## Infrared / Thermal Imaging
#     *    ### Predator
# -    ## Tomography (Cats scans)
# -    ## MRI
# -    ## Radar / Sonar
# -    ## Digital Photos
#     *    ### Remove Red-Eye
#
# -    ## Computer Graphics

# %% [markdown]
# # Image Processing
#
# -    ## Contrast Enhancement
# -    ## Denoising
# -    ## Deblurring (take away handshake from the camera)
# -    ## Inpainting (complete the missing data)
# -    ## Segmentation (Edge Detection)

# %% [markdown]
# # Video: W04_L09_P02

# %% [markdown]
# # Reading Image with PIL

# %% [markdown]
# ## Example1: Image.open & pylab.imshow
#
# -    ### Ref: http://programmingcomputervision.com/

# %%
from PIL import Image

# %%
im = Image.open("coffee.jpg")
im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1536x1265 at 0x46B8F38>

# %%
im_array = pylab.array(im)
im_array.shape
# Out:
# (1265, 1536, 3)

# %%
pylab.imshow(im_array)

# %% [markdown]
# ## Example2: Image.open().convert('L') & cm.Greys_r
#
# -    ### Ref: http://programmingcomputervision.com/
# -    ### Ref: http://stackoverflow.com/questions/3823752/display-image-as-grayscale-using-matplotlib

# %%
from PIL import Image
import matplotlib.cm as cm
im = Image.open("coffee.jpg").convert('L')
im_array = pylab.array(im)
print im_array.shape
pylab.imshow(im_array,cmap = cm.Greys_r)
# Out:
# (1265, 1536)

# %% [markdown]
# # Reading Image with OpenCV

# %% [markdown]
# ## Example1: cv2.imread & cv2.imshow
#
# -    ### Ref: http://docs.opencv.org/trunk/doc/py_tutorials/py_gui/py_image_display/py_image_display.html

# %%
import numpy as np
import cv2

# Load an color image in grayscale
img = cv2.imread('coffee.jpg')
img.shape
# Out:
# (1265, 1536, 3)

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# ## Example2: cv2.imread( ??? ,0)
#
# -    ### Ref: http://programmingcomputervision.com/
# -    ### Ref: http://stackoverflow.com/questions/3823752/display-image-as-grayscale-using-matplotlib

# %%
import numpy as np
import cv2

# Load an color image in grayscale
img = cv2.imread('coffee.jpg',0)
img.shape
# Out:
# (1265, 1536)

# %%
cv2.imshow('image',img)
cv2.waitKey(0)
cv2.destroyAllWindows()
