# %%
# %matplotlib inline

# %% [markdown]
# # Video: W01_L02_P02

# %%
import numpy as np
import pylab as pl

# %%
T = 30
n = 512

# %%
t2 = np.linspace(-T/2,T/2,n+1)
t = t2[:-1]
k = (2*np.pi/T)*np.fft.fftfreq(n,1.0/n)

# %%
u = 1/np.cosh(t)
pl.plot(t,u)

# %%
ks = np.fft.fftshift(k)
ut = np.fft.fft(u)
pl.subplot(2,1,1)
pl.plot(t,u)
pl.subplot(2,1,2)
pl.plot(ks,np.abs(np.fft.fftshift(ut)))

# %% [markdown]
# # Fourier Transform Pairs:
#
# - ## Gaussian (time) <=> Gaussian (freq)
# - ## Heisenberg Uncertainty principle
# - ## width of pulse in time <=> width of pulse in freq

# %%
pl.subplot(2,1,1)
pl.plot(t,u)
pl.subplot(2,1,2)
pl.plot(ks,np.abs(np.fft.fftshift(ut))/max(np.abs(np.fft.fftshift(ut))))
pl.xlim([-25,25])
pl.ylim([0,1])
# Out:
# (0, 1)

# %%
np.random.randn(1,n)
# Out:
# array([[-0.50534715,  0.04929331, -0.53575772,  2.1575913 , -0.28449838,
#          0.14369882, -0.96064137, -0.97753795,  0.74929413,  1.14960291,
#          1.98671292,  1.25497988, -0.13590743,  0.29186676, -0.26752845,
#         -0.61145793, -0.40957887, -1.1612689 ,  0.96190275, -0.54990502,
#         -2.56049939, -0.04473621,  0.70709309,  0.72551602,  0.23396428,
#          1.05462234, -0.53000693, -1.45431525, -0.0830451 ,  0.51062861,
#          1.69292864,  2.01870501, -0.01544161, -0.69929225,  0.01263621,
#         -0.61913553, -0.38930008,  1.35353743, -1.4776164 , -0.08899634,
#         -0.2580754 , -0.55451024, -1.07317031,  0.45458405,  0.37583921,
#         -0.36933456,  0.10999247, -1.29552728,  1.46287511, -0.91683557,
#          0.0924074 , -0.40617556,  0.59422658, -1.34569855,  2.1222851 ,
#          1.39840878, -0.10526604, -0.45096656, -1.25923854,  0.63032672,
#         -0.68245815,  1.29790078,  0.63229654, -0.90037688, -1.37162509,
#          1.18325661,  0.50638549,  0.76797449, -2.31484433, -0.20395147,
#          0.10025144, -1.56100141, -0.51717762,  0.65748757,  0.11643682,
#          0.645255  , -0.089164  , -0.37354048, -0.32854888, -0.47035322,
#          0.72659711,  0.4733174 ,  0.33644402, -0.77177806, -0.3771743 ,
#          1.61899919, -0.71236484,  0.46408246,  1.48337415,  1.45226027,
#          1.67180455, -2.00210468, -0.42140272,  0.24282216, -0.08945039,
#         -0.63805938,  0.85020876,  0.22075435, -0.74176685, -0.93271985,
#         -1.55641964,  0.2933222 , -1.02217764, -1.55441945, -0.50774658,
#          0.06129885,  1.73294052,  0.38134805, -0.50200098,  0.10213108,
#         -1.40614004, -0.10928007, -0.83989747, -0.19733579, -0.14555724,
#         -0.41793535,  0.85970877,  0.80457647,  0.42910749,  1.01641596,
#          0.02941374,  0.05045445,  0.41677877,  1.41165182,  1.1974405 ,
#          0.40328589,  0.01745319, -1.20876183,  0.42364226,  1.25494173,
#          0.41626832, -0.29130622, -0.4952852 , -1.07826328,  0.87247832,
#         -1.77247378, -1.04764197,  1.41673598, -1.50057035, -0.79875852,
#         -0.64264361, -0.44412488, -1.09126572,  0.02338823,  1.00355499,
#         -0.19569767,  1.95456032,  0.35724739,  0.22589099,  1.64815108,
#         -1.07106796,  1.16688679,  0.02426151,  0.14588703,  0.33038848,
#         -0.4471896 , -0.01844158,  0.09557839, -0.06562749, -0.10968163,
#         -0.21727806, -1.52810592,  1.1990686 ,  0.82081994, -0.42840223,
#         -0.44808194, -1.04053473, -0.41083478,  0.91176157,  0.84305749,
#          1.6071832 ,  1.31666284,  0.01670113,  1.45204475,  0.81069045,
#          1.15161397, -0.61262704,  0.17444086,  0.82566419,  0.62570813,
#         -0.06288177,  0.61872523, -0.21122141,  1.2549407 ,  0.80903532,
#          1.38419085, -0.51932297,  0.9467279 ,  0.81600159, -0.14709894,
#         -1.72496493, -0.89888606,  1.39465892,  1.2012905 ,  0.77466095,
#         -0.29395264, -0.51045619, -1.1445536 ,  0.43159161,  0.30470102,
#          1.73869252, -0.45409782, -0.48700116,  0.897227  ,  0.20750311,
#          0.80862543, -0.79358182, -1.06660765, -0.92214537,  1.06327464,
#         -0.96949451, -0.93392105, -1.15004188, -1.00838851, -0.51008558,
#         -0.05661537,  0.42533974,  0.03286832,  1.43886239,  2.0493392 ,
#          0.79085643, -2.11056157,  0.34251943, -0.09703661, -1.39229205,
#          0.08962893,  1.00414432, -1.31475259,  0.41938004, -1.0152349 ,
#          1.21371711,  0.31302471, -1.97165452,  0.56909629, -1.67209769,
#          0.43077546, -0.09420077, -0.67410457, -0.15531319, -0.83391154,
#          0.36774619,  0.0571015 ,  0.44062203, -1.15714701,  0.83877913,
#          1.21207401, -0.3626442 , -1.68188221, -0.02233761, -0.35937094,
#         -0.20452644, -1.26538649,  0.13758207,  0.28721587,  1.71382315,
#         -0.4409312 , -0.05913344, -1.04301974, -0.45065252,  0.16941127,
#          1.13846481, -0.17620584, -0.94653011, -1.36590163,  0.49516069,
#         -0.39378164,  0.2112552 , -0.45997197, -0.92481164,  0.32614252,
#          0.82967196,  1.02935204,  1.24985525, -1.01023152,  1.21455774,
#          0.18824345,  0.00341813,  1.11694174,  0.48814328, -1.31080395,
#          0.61166307,  1.91028629]])

# %% [markdown]
# # Video: W01_L02_P03

# %%
noise = 1
utn = ut + noise*(np.random.randn(1,n) + 1j*np.random.randn(1,n))
utn = utn.T
un = np.fft.fftshift(np.fft.ifft(utn))

# %%
# print ut.shape
# print utn.T.shape
# print len(t)
# print len(un)

# %%
pl.subplot(2,1,1)
pl.plot(t,u,"b",t,np.abs(un),"m")
pl.subplot(2,1,2)
pl.plot(ks,np.abs(np.fft.fftshift(ut))/max(np.abs(np.fft.fftshift(ut))),"b",
        ks,np.abs(np.fft.fftshift(utn))/max(np.abs(np.fft.fftshift(utn))),"m")
pl.xlim([-25,25])
pl.ylim([0,1])
# Out:
# (0, 1)

# %%
noise = 10
utn = ut + noise*(np.random.randn(1,n) + 1j*np.random.randn(1,n))
utn = utn.T
un = np.fft.fftshift(np.fft.ifft(utn))
pl.subplot(2,1,1)
pl.plot(t,u,"m",t,np.abs(un),"g")
pl.subplot(2,1,2)
pl.plot(ks,np.abs(np.fft.fftshift(ut))/max(np.abs(np.fft.fftshift(ut))),"b",
        ks,np.abs(np.fft.fftshift(utn))/max(np.abs(np.fft.fftshift(utn))),"m")
pl.xlim([-25,25])
pl.ylim([0,1])
# Out:
# (0, 1)

# %%
noise = 10
utn = ut + noise*(np.random.randn(1,n) + 1j*np.random.randn(1,n))
utn = utn.T
un = np.fft.fftshift(np.fft.ifft(utn))
pl.subplot(2,1,1)
pl.plot(t,np.abs(un),"m")
pl.subplot(2,1,2)
pl.plot(ks,np.abs(np.fft.fftshift(utn))/max(np.abs(np.fft.fftshift(utn))),"m")
pl.xlim([-25,25])
pl.ylim([0,1])
# Out:
# (0, 1)

# %% [markdown]
# # Q: if just look at time domain might say well, maybe there is something there?

# %%
noise = 20
utn = ut + noise*(np.random.randn(1,n) + 1j*np.random.randn(1,n))
utn = utn.T
un = np.fft.fftshift(np.fft.ifft(utn))
pl.subplot(2,1,1)
pl.plot(t,np.abs(un),"m")
pl.subplot(2,1,2)
pl.plot(ks,np.abs(np.fft.fftshift(utn))/max(np.abs(np.fft.fftshift(utn))),"m")
pl.xlim([-25,25])
pl.ylim([0,1])
# Out:
# (0, 1)

# %% [markdown]
# # Video: W01_L02_P04
