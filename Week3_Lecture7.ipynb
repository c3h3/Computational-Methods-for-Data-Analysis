# %%
# %matplotlib inline

# %%
import matplotlib.pylab as pylab
pylab.rcParams['figure.figsize'] = 16, 12

# %% [markdown]
# # Video: W03_L07_P01

# %% [markdown]
# ## [Marine Mammals Spectrogram](http://www.pmel.noaa.gov/acoustics/specs_whales.html)

# %% [markdown]
# # Initialize Setting:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
L = 10
n = 2048
t2 = np.linspace(0,L,n+1)
t = t2[:-1]
k = (2*np.pi/L)*np.fft.fftfreq(n,1.0/n)
ks = np.fft.ifftshift(k)

# %% [markdown]
# # Create and Plot the Signal:

# %%
#Sample_Signal
S = (3*np.sin(2*t) + 0.5*np.tanh(0,5*(t-3)) + 0.28*np.exp(-(t-4)**2) \
+ 1.5*np.sin(5*t) + 4*np.cos(3*(t-6)**2))/10 + (t/20)**3

# %%
plt.plot(t,S)

# %% [markdown]
# # Compute and Plot FFT of the Signal:

# %%
St = np.fft.fft(S)

# %%
plt.subplot(2,1,1)
plt.plot(t,S)
plt.subplot(2,1,2)
plt.plot(ks,np.abs(np.fft.fftshift(St)))

# %% [markdown]
# # Zoom In the second figure:

# %%
plt.subplot(2,1,1)
plt.plot(t,S)
plt.subplot(2,1,2)
plt.plot(ks,np.abs(np.fft.fftshift(St)))
plt.xlim(-50, 50)
# Out:
# (-50, 50)

# %% [markdown]
# # Re-Scaling and ZoomIn second figure:

# %%
plt.subplot(2,1,1)
plt.plot(t,S)
plt.subplot(2,1,2)
plt.plot(ks,np.abs(np.fft.fftshift(St))/max(np.abs(np.fft.fftshift(St))))
plt.xlim(-50, 50)
# Out:
# (-50, 50)

# %% [markdown]
# # Video: W03_L07_P02

# %% [markdown]
# # Create Windows with Different Sizes:

# %%
width_list = [10.0,1.0,0.2]

for i in range(3):
    f = np.exp(-width_list[i]*(t-4)**2)
    plt.subplot(3,1,i+1)
    plt.plot(t,S,"k",t,f,"m")

# %%
width = 1
slides = np.arange(0,10,0.1)
for i in range(len(slides)):
    f = np.exp(-width*(t-slides[i])**2)
    
#     plt.subplot(3,1,i+1)
#     plt.plot(t,S,"k",t,f,"m")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-46ec5285af0b> in <module>()
#       3 for i in range(len(slides)):
#       4     f = np.exp(-width*(t-4)**2)
# ----> 5     plt.subplot(3,1,i+1)
#       6     plt.plot(t,S,"k",t,f,"m")
#       7
#
# /usr/lib/pymodules/python2.7/matplotlib/pyplot.pyc in subplot(*args, **kwargs)
#
# /usr/lib/pymodules/python2.7/matplotlib/figure.pyc in add_subplot(self, *args, **kwargs)
#
# /usr/lib/pymodules/python2.7/matplotlib/axes.pyc in __init__(self, fig, *args, **kwargs)
#
# /usr/lib/pymodules/python2.7/matplotlib/gridspec.pyc in __getitem__(self, key)
#
# IndexError: index out of range

# %% [markdown]
# (06:08)
